# %%
import os
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import SentenceTransformerEmbeddings
from langchain.vectorstores import FAISS
from langchain.chains.question_answering import load_qa_chain
from langchain_community.llms import LlamaCpp
import pypdf

# %%
docs = []
for fname in os.listdir("../docs"):
    if fname.lower().endswith(".pdf"):
        loader = PyPDFLoader(f"../docs/{fname}")
        for i, page in enumerate(loader.load(), start = 1):
            page.metadata["source"] = fname
            page.metadata["page"] = i
            docs.append(page)
print(f"Loaded {len(docs)} pages from {len(set(d.metadata['source'] for d in docs))} PDFs")
# Out:
# Loaded 8 pages from 1 PDFs

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
chunks = splitter.split_documents(docs)
print(f"Created {len(chunks)} chunks.")
# Out:
# Created 19 chunks.

# %%
embeddings = SentenceTransformerEmbeddings(model_name = "all-MiniLM-L6-v2")
index = FAISS.from_documents(chunks, embeddings)
index.save_local("../faiss_multi_index")

# %%
index = FAISS.load_local(
    "../faiss_multi_index",
    embeddings,
    allow_dangerous_deserialization = True
    )
retriever = index.as_retriever(search_kwargs={"k":4})

# %%
llm = LlamaCpp(
    model_path = "../models/llama-2-7b-chat.Q4_K_M.gguf",
    temperature = 0.0,
    n_ctx = 2048,
    n_gou_layers = 20,
    verbose = False)
qa_chain = load_qa_chain(llm, chain_type = "stuff")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/miniconda3/envs/rag-env/lib/python3.10/site-packages/langchain_community/llms/llamacpp.py:140, in LlamaCpp.validate_environment(cls, values)
#     139 try:
# --> 140     from llama_cpp import Llama, LlamaGrammar
#     141 except ImportError:
#
# ModuleNotFoundError: No module named 'llama_cpp'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 llm = LlamaCpp(
#       2     model_path = "../models/llama-2-7b-chat.Q4_K_M.gguf",
#       3     temperature = 0.0,
#       4     n_ctx = 2048,
#       5     n_gou_layers = 20,
#       6     verbose = False)
#       7 qa_chain = load_qa_chain(llm, chain_type = "stuff")
#
# ...

# %%
def answer_with_citations(question):
    docs = retriever.get_relevant_documents(question)
    answer = qa_chain.run(input_documents = docs, question = question)
    cites = []
    for d in docs:
        cites.append(f"{d.metadata['source']}, p. {d.metadata['page']}")
    cites = list(dict.fromkeys(cites))
    return answer, cites

# %%
question = input("Ask a question: ")
if question.lower() not in ("exit", "quit"):
    ans, sources = answer_with_citations(question)
    print("\nAnswer:\n", ans)
    for s in sources:
        print(" -", s)
# Out:
# Ask a question:  what is sum
# /tmp/ipykernel_370616/3692525822.py:2: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   docs = retriever.get_relevant_documents(question)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 question = input("Ask a question: ")
#       2 if question.lower() not in ("exit", "quit"):
# ----> 3     ans, sources = answer_with_citations(question)
#       4     print("\nAnswer:\n", ans)
#       5     for s in sources:
#
# Cell In[19], line 3, in answer_with_citations(question)
#       1 def answer_with_citations(question):
#       2     docs = retriever.get_relevant_documents(question)
# ----> 3     answer = qa_chain.run(input_documents = docs, question = question)
#       4     cites = []
# ...
